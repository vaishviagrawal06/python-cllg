# %% [markdown]
# x() --> (iske andar kuch bhi likho vo print karke de dega)
# it is a case sensitive language

# %%
print("hello world")
# Out:
# hello world

# %%
print(vaishvi agrawal)
# Out:
#   Cell In[2], line 1
#     print(vaishvi agrawal)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(7)
print(7.7)
print(True)
# Out:
# 7
# 7.7
# True

# %%
print("hello",4,4.5)
# Out:
# hello 4 4.5

# %%
print("hello",123,True,sep=',')
# Out:
# hello,123,True

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world
