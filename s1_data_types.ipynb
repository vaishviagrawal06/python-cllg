# %% [markdown]
# =================DATA TYPES==============
# integer

# %%
#integer
print(8)
print(1e309)  # matlab 1*10 ki power 309
# Out:
# 8
# inf

# %%
#decimal/float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#text/string
print('hello world')
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list -> c-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({'name':'nitesh','gender':'male','weight':70})
# Out:
# {'name': 'nitesh', 'gender': 'male', 'weight': 70}

# %%
#type
type([1,2,3])
# Out:
# list

# %% [markdown]
# static vs dynamic typing
# static vs dynamic binding
# stylish declaration techniques

# %%
#c/c++
name = 'vaishvi'
print(name)

a=5
b=6

print(a+b)
# Out:
# vaishvi
# 11

# %%
#dynamic typing
a=5
#static typing
# int b = 5

# %%
#dynamic binding
a=5
print(a)
a='vaishvi'
print(a)
# Out:
# 5
# vaishvi

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# ==============KEYWORDS AND IDENTIFIERS==============

# %%
#identifiers
#you can't start with a digit
name1='vaishvi'
print(name1)

#can use special chars -> _
_='vaishvi'
print(_)
# Out:
# vaishvi
# vaishvi

# %% [markdown]
# ==============USER INPUT=============

# %%
#static vs dynamic
input('enter email')
# Out:
# 'hello.06@gamil.com'

# %%
# take input from users and store them in a variable
n1=(input("enter first number"))
n2=(input("enter second number"))  # isme type input ke according aayega

result =int(n1)+int(n2)
print(result)
print(type(n1))
# Out:
# 3
# <class 'str'>

# %%
n1=int(input("enter first number"))
n2=int(input("enter second number"))   #isme se type hamesha int aayega 

result = n1 + n2

print(result)
print(type(n1),type(n2))
# Out:
# 3
# <class 'int'> <class 'int'>

# %% [markdown]
# ============TYPE CONVERSION============

# %%
#implicit vs explicit
# implicit -> type conversion internally ho jaaye
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#explicit
# str -> int
# int(4+5j)  # cannot convert complex into int

#int to str
str(5)

#float
float(4)
# Out:
# 4.0

# %% [markdown]
# ===========LITERALS=============
# variable ke andar jo value ko store karte ho use literal kehte hai

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"  # isme emoji vagera print karwa sakte hai
raw_str = r"raw \n string"   # iske andar \n vagera likh sakte hai

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)

# %%
a=True+5
b=False+11

print("a:",a)
print("b:",b)
# Out:
# a: 6
# b: 11
