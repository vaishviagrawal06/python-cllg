# %% [markdown]
# wap which will print Fizz if the no. is divisible by 3 Buzz if the no is div by 5 and fizzBuzz if divisible by both 3 and 5

# %%
for n in (1,31):
    if n %3 == 0 and n%5==0:
      print("FizzBuzz")
    elif n%3 ==0 :
     print("Fizz")
    elif n%5 ==0 :
     print("buzz")
    else:
     print(n,end = " ")
# Out:
# buzz

# %% [markdown]
# Wap to taking a no from user And print its factor.

# %%
n = int(input("enter number :"))
print("Factors of", n, "are:")
for i in range(1,n+1):
    if n%i==0:
       
        print(i)
# Out:
# Factors of 12 are:
# 1
# 2
# 3
# 4
# 6
# 12

# %%
n = int(input("enter the number"))
even = 0
odd =0
for i in range(1,n+1):
    if n%i ==0:
        print(i,end =" ")
        if i%2==0:
            even +=1
        else:
            odd+=1
print("odd factors are: ",odd,"even factors are ",even)
# Out:
# 1 2 3 4 6 12 odd factors are:  2 even factors are  4

# %%
for i in range(2,31,2):
    print(i,end=" ")
    # end use karne se pura ek hi line me print hoga space doge to space , doge to comma
