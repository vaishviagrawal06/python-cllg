# %%
x = eval(input())
print(type(x))
print(x)

# output : 
# <class 'tuple'>
# (1, 2, 3, 4, 5, 6)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5, 6)

# %%
lst = [13,14,10,23,15,26]

print(lst)
for i in range (len(lst)):
    if lst[i]%2==0:
        lst[i]-=5
    else:
        lst[i]+=5
print(lst)
# Out:
# [13, 14, 10, 23, 15, 26]
# [18, 9, 5, 28, 20, 21]
