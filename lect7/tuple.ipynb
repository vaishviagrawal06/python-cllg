# %% [markdown]
# tuple --> immutable
# use parenthesis
# changes nhi kar sakte baad me
# tple = 1,2,3,4,'helllo'  --> bydefault tuple lega parenthess na bhi lagao ge to
# tuple ko sirf delete kar sakte ho bs
# vo bhi single ele. nhi pura list hi delete hoga

# %%
#  EMPTY TUPLE 
tpl =()
tpl1 = tuple()
print(tpl,tpl1)
# Out:
# () ()

# %%
tpl =(1)
print(type(tpl))
print(tpl)
# Out:
# <class 'int'>
# 1

# %%
tpl = (2,3,5,6,"hello")
tpl+=(4,7,8,9)
print(tpl) 
# aisa isiliye hua kyunki jo dusra tpl hai vo naya list hai 
# dono data ka address different aayega
# Out:
# (2, 3, 5, 6, 'hello', 4, 7, 8, 9)

# %%
tpl = (2,3,4,5,"hello")
tpl=list(tpl)
tpl[3]=90
tpl = tuple(tpl)
print(tpl)
# Out:
# (2, 3, 4, 90, 'hello')

# %%
tpl =[2,3,4,5,6,8,9,12,14,24,45]
print(sorted(tpl,reverse=True))
# Out:
# [45, 24, 14, 12, 9, 8, 6, 5, 4, 3, 2]

# %%
tpl =[2,3,4,5,6,8,9,12,14,24,45]
tpl[-3::-6]
# output : [14,4]
# Out:
# [14, 4]
