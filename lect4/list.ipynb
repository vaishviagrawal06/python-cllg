# %%
# Create empty list
lst=[]
lst1=list()
print(lst)
print(lst1)
# Out:
# []
# []

# %%
lst = [3,5,7,9,11]
print(lst[3])
print(lst[-2])
# Out:
# 9
# 9

# %%
lst=[1,2,3,4,5,"hello",[3,4,5],8]
print(lst[6][-2])
# Out:
# 4

# %%
lst=[1,2,3,4.5,"hello",[3,4,5],8]
for i in range(len(lst)):
    print(lst[i])
    # pehle index generate kar raha hai then traverse kar raha hai
    print(lst[i],end = " ")

# %%
# directly element access karna hai
for i in lst:
    print(i,end=" ")
# Out:
# 1 2 3 4 5 hello [3, 4, 5] 8
