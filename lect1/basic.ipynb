# %%
name = input("enter your name")
print(name)
age = int(input("enter your age"))
height=float(input("enter your height"))
print("my name is ",name,"age ",age, "and height",height)
# Out:
# vaishvi
# my name is  vaishvi age  20 and height 5.2

# %%
x=5
y=7
z=5
print(id(x),id(y),id(z))
y=9
print(id(x),id(y),id(z))
# Out:
# 140737261970680 140737261970744 140737261970680
# 140737261970680 140737261970808 140737261970680

# %%
# wap to take radius of circle as input and print circumference of circle
r = float(int("enter radius"))
a = 3.14*r*r
c=2*3.14*r
print("area of circumference is",a," ",c)

# %%
# wap which will take length and breadth a input and print area of rectangle
length= int(input("enter length"))
breadth=int(input("enter breadth"))
area = length*breadth
print("area of rectangle is ",area)
# Out:
# area of rectangle is  16

# %%
print("hello world")
# Out:
# hello world
