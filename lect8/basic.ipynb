# %%
x = "hello everyone lets learn python"

lst = x.split()
print(lst)

reverse1 = lst[::-1]
reverse = x[::-1]

result = "".join(reverse)
print (result)


result1 = " ".join(reverse1)
print ((result1).capitalize())
# Out:
# ['hello', 'everyone', 'lets', 'learn', 'python']
# nohtyp nrael stel enoyreve olleh
# Python learn lets everyone hello

# %%
x = "hello everyone lets learn python"

print(" ".join(x.split()[::-1]).capitalize())
# Out:
# Python learn lets everyone hello

# %%
email = input("enter email: ")

if "@" in email and "."in email:
    if email.index("@")<email.index("."):
        print("valid email...")
    else:
        print("invalid email...")
else:
    print("invalid email")
# Out:
# invalid email...

# %%
x = "Hello World from Python"

print(" ".join(x.split()[::-1]))
# Out:
# Python from World Hello

# %%
string = input("enter a string")
char = input("enter a character")

indices =[]
for i in range(len(string)):
    if string[i] == char:
        indices.append(i)
print(indices)
# Out:
# [6, 7]

# %%
x="this is a test string for testing"
string = input("enter a string you want to remove")

result = x.replace(string,"")
print(result)
# Out:
# this is a  string for ing
